# %% [markdown]
# ### seq2seq

# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse =  True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hideen_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 일반 혹은 엿보기(Peeky) 설정 =====================================
model = Seq2seq(vocab_size, wordvec_size, hideen_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hideen_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.52
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 2[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 2[s] | 손실 1.91
# | 에폭 1 |  반복 101 / 351 | 시간 3[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 4[s] | 손실 1.86
# | 에폭 1 |  반복 141 / 351 | 시간 4[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 5[s] | 손실 1.80
# | 에폭 1 |  반복 181 / 351 | 시간 5[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 6[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 7[s] | 손실 1.77
# | 에폭 1 |  반복 241 / 351 | 시간 7[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 8[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 8[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 9[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 10[s] | 손실 1.74
# | 에폭 1 |  반복 341 / 351 | 시간 10[s] | 손실 1.73
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1001
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1001
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 1001
# ---
# Q 143+93
# T 236
# X 703
# ---
# 검증 정확도 0.120%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 41 / 351 | 시간 1[s] | 손실 1.72
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.72
# | 에폭 2 |  반복 81 / 351 | 시간 2[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 3[s] | 손실 1.70
# | 에폭 2 |  반복 121 / 351 | 시간 4[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 4[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 5[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 6[s] | 손실 1.66
# | 에폭 2 |  반복 201 / 351 | 시간 6[s] | 손실 1.66
# | 에폭 2 |  반복 221 / 351 | 시간 7[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 8[s] | 손실 1.63
# | 에폭 2 |  반복 261 / 351 | 시간 8[s] | 손실 1.62
# | 에폭 2 |  반복 281 / 351 | 시간 9[s] | 손실 1.61
# | 에폭 2 |  반복 301 / 351 | 시간 10[s] | 손실 1.60
# | 에폭 2 |  반복 321 / 351 | 시간 10[s] | 손실 1.58
# | 에폭 2 |  반복 341 / 351 | 시간 11[s] | 손실 1.56
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 690
# ---
# Q 8+155
# T 163
# X 1000
# ---
# Q 367+55
# T 422
# X 470
# ---
# Q 600+257
# T 857
# X 700
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1444
# ---
# Q 26+838
# T 864
# X 700
# ---
# Q 143+93
# T 236
# X 370
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.52
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.53
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.51
# | 에폭 3 |  반복 61 / 351 | 시간 2[s] | 손실 1.49
# | 에폭 3 |  반복 81 / 351 | 시간 2[s] | 손실 1.47
# | 에폭 3 |  반복 101 / 351 | 시간 3[s] | 손실 1.45
# | 에폭 3 |  반복 121 / 351 | 시간 4[s] | 손실 1.44
# | 에폭 3 |  반복 141 / 351 | 시간 4[s] | 손실 1.42
# | 에폭 3 |  반복 161 / 351 | 시간 5[s] | 손실 1.40
# | 에폭 3 |  반복 181 / 351 | 시간 5[s] | 손실 1.38
# | 에폭 3 |  반복 201 / 351 | 시간 6[s] | 손실 1.37
# | 에폭 3 |  반복 221 / 351 | 시간 7[s] | 손실 1.35
# | 에폭 3 |  반복 241 / 351 | 시간 7[s] | 손실 1.33
# | 에폭 3 |  반복 261 / 351 | 시간 8[s] | 손실 1.32
# | 에폭 3 |  반복 281 / 351 | 시간 9[s] | 손실 1.30
# | 에폭 3 |  반복 301 / 351 | 시간 9[s] | 손실 1.29
# | 에폭 3 |  반복 321 / 351 | 시간 10[s] | 손실 1.28
# | 에폭 3 |  반복 341 / 351 | 시간 11[s] | 손실 1.27
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1148
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 382
# ---
# Q 600+257
# T 857
# X 818
# ---
# Q 761+292
# T 1053
# X 1008
# ---
# Q 830+597
# T 1427
# X 1434
# ---
# Q 26+838
# T 864
# X 838
# ---
# Q 143+93
# T 236
# X 202
# ---
# 검증 정확도 1.940%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.26
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.25
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.23
# | 에폭 4 |  반복 61 / 351 | 시간 2[s] | 손실 1.22
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.20
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 1.19
# | 에폭 4 |  반복 121 / 351 | 시간 4[s] | 손실 1.18
# | 에폭 4 |  반복 141 / 351 | 시간 4[s] | 손실 1.17
# | 에폭 4 |  반복 161 / 351 | 시간 5[s] | 손실 1.15
# | 에폭 4 |  반복 181 / 351 | 시간 6[s] | 손실 1.13
# | 에폭 4 |  반복 201 / 351 | 시간 7[s] | 손실 1.12
# | 에폭 4 |  반복 221 / 351 | 시간 7[s] | 손실 1.11
# | 에폭 4 |  반복 241 / 351 | 시간 8[s] | 손실 1.09
# | 에폭 4 |  반복 261 / 351 | 시간 9[s] | 손실 1.08
# | 에폭 4 |  반복 281 / 351 | 시간 10[s] | 손실 1.07
# | 에폭 4 |  반복 301 / 351 | 시간 10[s] | 손실 1.07
# | 에폭 4 |  반복 321 / 351 | 시간 11[s] | 손실 1.05
# | 에폭 4 |  반복 341 / 351 | 시간 12[s] | 손실 1.03
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1196
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 896
# ---
# Q 761+292
# T 1053
# X 1010
# ---
# Q 830+597
# T 1427
# X 1496
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 5.780%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 5 |  반복 101 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 5 |  반복 141 / 351 | 시간 4[s] | 손실 0.94
# | 에폭 5 |  반복 161 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 5 |  반복 181 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 5 |  반복 201 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 5 |  반복 221 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 5 |  반복 241 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 5 |  반복 261 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 5 |  반복 281 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 5 |  반복 301 / 351 | 시간 10[s] | 손실 0.86
# | 에폭 5 |  반복 321 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 5 |  반복 341 / 351 | 시간 11[s] | 손실 0.84
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1192
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 860
# ---
# Q 761+292
# T 1053
# X 1066
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 232
# ---
# 검증 정확도 12.460%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 6 |  반복 61 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 6 |  반복 101 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 6 |  반복 121 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 6 |  반복 161 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 6 |  반복 181 / 351 | 시간 6[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 6 |  반복 221 / 351 | 시간 7[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 8[s] | 손실 0.75
# | 에폭 6 |  반복 261 / 351 | 시간 9[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 10[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 10[s] | 손실 0.73
# | 에폭 6 |  반복 321 / 351 | 시간 11[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 12[s] | 손실 0.72
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1141
# ---
# Q 582+84
# T 666
# X 661
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1061
# ---
# Q 830+597
# T 1427
# X 1391
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 234
# ---
# 검증 정확도 14.260%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 7 |  반복 61 / 351 | 시간 2[s] | 손실 0.70
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 7 |  반복 101 / 351 | 시간 3[s] | 손실 0.68
# | 에폭 7 |  반복 121 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 7 |  반복 141 / 351 | 시간 4[s] | 손실 0.67
# | 에폭 7 |  반복 161 / 351 | 시간 5[s] | 손실 0.67
# | 에폭 7 |  반복 181 / 351 | 시간 6[s] | 손실 0.66
# | 에폭 7 |  반복 201 / 351 | 시간 7[s] | 손실 0.66
# | 에폭 7 |  반복 221 / 351 | 시간 7[s] | 손실 0.66
# | 에폭 7 |  반복 241 / 351 | 시간 8[s] | 손실 0.64
# | 에폭 7 |  반복 261 / 351 | 시간 9[s] | 손실 0.65
# | 에폭 7 |  반복 281 / 351 | 시간 10[s] | 손실 0.64
# | 에폭 7 |  반복 301 / 351 | 시간 10[s] | 손실 0.63
# | 에폭 7 |  반복 321 / 351 | 시간 11[s] | 손실 0.63
# | 에폭 7 |  반복 341 / 351 | 시간 12[s] | 손실 0.62
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1144
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 17.500%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.61
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.62
# | 에폭 8 |  반복 61 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 101 / 351 | 시간 3[s] | 손실 0.61
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 8 |  반복 141 / 351 | 시간 4[s] | 손실 0.60
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 8 |  반복 181 / 351 | 시간 5[s] | 손실 0.58
# | 에폭 8 |  반복 201 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 8 |  반복 221 / 351 | 시간 7[s] | 손실 0.60
# | 에폭 8 |  반복 241 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 8 |  반복 261 / 351 | 시간 8[s] | 손실 0.58
# | 에폭 8 |  반복 281 / 351 | 시간 8[s] | 손실 0.59
# | 에폭 8 |  반복 301 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 8 |  반복 321 / 351 | 시간 10[s] | 손실 0.57
# | 에폭 8 |  반복 341 / 351 | 시간 11[s] | 손실 0.57
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1134
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 759
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 23.080%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.56
# | 에폭 9 |  반복 61 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.54
# | 에폭 9 |  반복 101 / 351 | 시간 3[s] | 손실 0.55
# | 에폭 9 |  반복 121 / 351 | 시간 4[s] | 손실 0.55
# | 에폭 9 |  반복 141 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 9 |  반복 161 / 351 | 시간 5[s] | 손실 0.55
# | 에폭 9 |  반복 181 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 9 |  반복 201 / 351 | 시간 7[s] | 손실 0.54
# | 에폭 9 |  반복 221 / 351 | 시간 8[s] | 손실 0.54
# | 에폭 9 |  반복 241 / 351 | 시간 8[s] | 손실 0.53
# | 에폭 9 |  반복 261 / 351 | 시간 9[s] | 손실 0.53
# | 에폭 9 |  반복 281 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 9 |  반복 301 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 9 |  반복 321 / 351 | 시간 11[s] | 손실 0.53
# | 에폭 9 |  반복 341 / 351 | 시간 12[s] | 손실 0.53
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# X 664
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 26.540%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.52
# | 에폭 10 |  반복 61 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.52
# | 에폭 10 |  반복 101 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 10 |  반복 121 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 10 |  반복 141 / 351 | 시간 4[s] | 손실 0.51
# | 에폭 10 |  반복 161 / 351 | 시간 5[s] | 손실 0.52
# | 에폭 10 |  반복 181 / 351 | 시간 6[s] | 손실 0.53
# | 에폭 10 |  반복 201 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 10 |  반복 221 / 351 | 시간 7[s] | 손실 0.50
# | 에폭 10 |  반복 241 / 351 | 시간 8[s] | 손실 0.50
# | 에폭 10 |  반복 261 / 351 | 시간 9[s] | 손실 0.50
# | 에폭 10 |  반복 281 / 351 | 시간 9[s] | 손실 0.49
# | 에폭 10 |  반복 301 / 351 | 시간 10[s] | 손실 0.48
# | 에폭 10 |  반복 321 / 351 | 시간 11[s] | 손실 0.48
# | 에폭 10 |  반복 341 / 351 | 시간 12[s] | 손실 0.48
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 664
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 29.820%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.48
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 11 |  반복 141 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 11 |  반복 161 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 11 |  반복 181 / 351 | 시간 6[s] | 손실 0.48
# | 에폭 11 |  반복 201 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 11 |  반복 221 / 351 | 시간 7[s] | 손실 0.47
# | 에폭 11 |  반복 241 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 11 |  반복 261 / 351 | 시간 9[s] | 손실 0.46
# | 에폭 11 |  반복 281 / 351 | 시간 10[s] | 손실 0.46
# | 에폭 11 |  반복 301 / 351 | 시간 10[s] | 손실 0.48
# | 에폭 11 |  반복 321 / 351 | 시간 11[s] | 손실 0.45
# | 에폭 11 |  반복 341 / 351 | 시간 12[s] | 손실 0.45
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 28.460%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 12 |  반복 61 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 12 |  반복 101 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 12 |  반복 121 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 12 |  반복 141 / 351 | 시간 5[s] | 손실 0.46
# | 에폭 12 |  반복 161 / 351 | 시간 5[s] | 손실 0.45
# | 에폭 12 |  반복 181 / 351 | 시간 6[s] | 손실 0.44
# | 에폭 12 |  반복 201 / 351 | 시간 7[s] | 손실 0.45
# | 에폭 12 |  반복 221 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 12 |  반복 241 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 12 |  반복 261 / 351 | 시간 9[s] | 손실 0.43
# | 에폭 12 |  반복 281 / 351 | 시간 10[s] | 손실 0.44
# | 에폭 12 |  반복 301 / 351 | 시간 11[s] | 손실 0.45
# | 에폭 12 |  반복 321 / 351 | 시간 11[s] | 손실 0.44
# | 에폭 12 |  반복 341 / 351 | 시간 12[s] | 손실 0.43
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 36.640%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 61 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 13 |  반복 121 / 351 | 시간 4[s] | 손실 0.43
# | 에폭 13 |  반복 141 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 13 |  반복 161 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 13 |  반복 181 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 13 |  반복 201 / 351 | 시간 7[s] | 손실 0.42
# | 에폭 13 |  반복 221 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 13 |  반복 241 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 13 |  반복 261 / 351 | 시간 9[s] | 손실 0.41
# | 에폭 13 |  반복 281 / 351 | 시간 10[s] | 손실 0.42
# | 에폭 13 |  반복 301 / 351 | 시간 11[s] | 손실 0.41
# | 에폭 13 |  반복 321 / 351 | 시간 11[s] | 손실 0.43
# | 에폭 13 |  반복 341 / 351 | 시간 12[s] | 손실 0.40
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 424
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 239
# ---
# 검증 정확도 39.420%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 14 |  반복 61 / 351 | 시간 2[s] | 손실 0.40
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.40
# | 에폭 14 |  반복 101 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 14 |  반복 121 / 351 | 시간 4[s] | 손실 0.39
# | 에폭 14 |  반복 141 / 351 | 시간 5[s] | 손실 0.39
# | 에폭 14 |  반복 161 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 14 |  반복 181 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 14 |  반복 201 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 14 |  반복 221 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 14 |  반복 241 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 14 |  반복 261 / 351 | 시간 9[s] | 손실 0.40
# | 에폭 14 |  반복 281 / 351 | 시간 10[s] | 손실 0.41
# | 에폭 14 |  반복 301 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 14 |  반복 321 / 351 | 시간 11[s] | 손실 0.39
# | 에폭 14 |  반복 341 / 351 | 시간 12[s] | 손실 0.39
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# 검증 정확도 36.640%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.39
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 101 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 15 |  반복 121 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 141 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 161 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 15 |  반복 181 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 15 |  반복 201 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 15 |  반복 221 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 15 |  반복 241 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 15 |  반복 261 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 15 |  반복 281 / 351 | 시간 9[s] | 손실 0.37
# | 에폭 15 |  반복 301 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 15 |  반복 321 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 15 |  반복 341 / 351 | 시간 11[s] | 손실 0.37
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 41.100%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 16 |  반복 101 / 351 | 시간 3[s] | 손실 0.36
# | 에폭 16 |  반복 121 / 351 | 시간 4[s] | 손실 0.37
# | 에폭 16 |  반복 141 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 16 |  반복 161 / 351 | 시간 5[s] | 손실 0.37
# | 에폭 16 |  반복 181 / 351 | 시간 6[s] | 손실 0.36
# | 에폭 16 |  반복 201 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 16 |  반복 221 / 351 | 시간 8[s] | 손실 0.38
# | 에폭 16 |  반복 241 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 16 |  반복 261 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 16 |  반복 281 / 351 | 시간 10[s] | 손실 0.35
# | 에폭 16 |  반복 301 / 351 | 시간 10[s] | 손실 0.35
# | 에폭 16 |  반복 321 / 351 | 시간 11[s] | 손실 0.35
# | 에폭 16 |  반복 341 / 351 | 시간 12[s] | 손실 0.37
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 42.700%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 17 |  반복 121 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 17 |  반복 141 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 17 |  반복 161 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 17 |  반복 181 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 17 |  반복 201 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 17 |  반복 221 / 351 | 시간 8[s] | 손실 0.34
# | 에폭 17 |  반복 241 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 17 |  반복 261 / 351 | 시간 9[s] | 손실 0.36
# | 에폭 17 |  반복 281 / 351 | 시간 10[s] | 손실 0.37
# | 에폭 17 |  반복 301 / 351 | 시간 10[s] | 손실 0.37
# | 에폭 17 |  반복 321 / 351 | 시간 11[s] | 손실 0.37
# | 에폭 17 |  반복 341 / 351 | 시간 12[s] | 손실 0.36
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 42.840%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 61 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 18 |  반복 101 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 18 |  반복 121 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 18 |  반복 141 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 161 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 18 |  반복 181 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 18 |  반복 201 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 221 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 241 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 18 |  반복 261 / 351 | 시간 9[s] | 손실 0.33
# | 에폭 18 |  반복 281 / 351 | 시간 10[s] | 손실 0.33
# | 에폭 18 |  반복 301 / 351 | 시간 10[s] | 손실 0.33
# | 에폭 18 |  반복 321 / 351 | 시간 11[s] | 손실 0.35
# | 에폭 18 |  반복 341 / 351 | 시간 12[s] | 손실 0.35
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1425
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 40.640%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 19 |  반복 61 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 19 |  반복 101 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 19 |  반복 121 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 19 |  반복 141 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 19 |  반복 161 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 19 |  반복 181 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 19 |  반복 201 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 19 |  반복 221 / 351 | 시간 8[s] | 손실 0.31
# | 에폭 19 |  반복 241 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 19 |  반복 261 / 351 | 시간 9[s] | 손실 0.33
# | 에폭 19 |  반복 281 / 351 | 시간 10[s] | 손실 0.33
# | 에폭 19 |  반복 301 / 351 | 시간 11[s] | 손실 0.32
# | 에폭 19 |  반복 321 / 351 | 시간 11[s] | 손실 0.33
# | 에폭 19 |  반복 341 / 351 | 시간 12[s] | 손실 0.33
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 47.540%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 20 |  반복 61 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.31
# | 에폭 20 |  반복 101 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 20 |  반복 121 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 20 |  반복 141 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 20 |  반복 161 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 20 |  반복 181 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 20 |  반복 201 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 20 |  반복 221 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 20 |  반복 241 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 20 |  반복 261 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 20 |  반복 281 / 351 | 시간 10[s] | 손실 0.36
# | 에폭 20 |  반복 301 / 351 | 시간 10[s] | 손실 0.34
# | 에폭 20 |  반복 321 / 351 | 시간 11[s] | 손실 0.32
# | 에폭 20 |  반복 341 / 351 | 시간 12[s] | 손실 0.32
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 50.140%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.30
# | 에폭 21 |  반복 61 / 351 | 시간 2[s] | 손실 0.30
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.32
# | 에폭 21 |  반복 101 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 21 |  반복 121 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 21 |  반복 141 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 21 |  반복 161 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 21 |  반복 181 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 21 |  반복 201 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 21 |  반복 221 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 21 |  반복 241 / 351 | 시간 8[s] | 손실 0.31
# | 에폭 21 |  반복 261 / 351 | 시간 9[s] | 손실 0.29
# | 에폭 21 |  반복 281 / 351 | 시간 10[s] | 손실 0.30
# | 에폭 21 |  반복 301 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 21 |  반복 321 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 21 |  반복 341 / 351 | 시간 12[s] | 손실 0.29
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 50.880%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 22 |  반복 61 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 22 |  반복 101 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 22 |  반복 121 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 22 |  반복 141 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 22 |  반복 161 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 22 |  반복 181 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 22 |  반복 201 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 22 |  반복 221 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 22 |  반복 241 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 22 |  반복 261 / 351 | 시간 9[s] | 손실 0.32
# | 에폭 22 |  반복 281 / 351 | 시간 10[s] | 손실 0.31
# | 에폭 22 |  반복 301 / 351 | 시간 10[s] | 손실 0.30
# | 에폭 22 |  반복 321 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 22 |  반복 341 / 351 | 시간 12[s] | 손실 0.31
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 47.760%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 23 |  반복 61 / 351 | 시간 2[s] | 손실 0.28
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 23 |  반복 101 / 351 | 시간 3[s] | 손실 0.27
# | 에폭 23 |  반복 121 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 23 |  반복 141 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 23 |  반복 161 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 23 |  반복 181 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 23 |  반복 201 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 23 |  반복 221 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 23 |  반복 241 / 351 | 시간 8[s] | 손실 0.28
# | 에폭 23 |  반복 261 / 351 | 시간 9[s] | 손실 0.28
# | 에폭 23 |  반복 281 / 351 | 시간 10[s] | 손실 0.30
# | 에폭 23 |  반복 301 / 351 | 시간 10[s] | 손실 0.29
# | 에폭 23 |  반복 321 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 23 |  반복 341 / 351 | 시간 12[s] | 손실 0.28
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# 검증 정확도 45.160%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 24 |  반복 61 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.30
# | 에폭 24 |  반복 101 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 24 |  반복 121 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 24 |  반복 141 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 24 |  반복 161 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 24 |  반복 181 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 24 |  반복 201 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 24 |  반복 221 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 24 |  반복 241 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 24 |  반복 261 / 351 | 시간 9[s] | 손실 0.29
# | 에폭 24 |  반복 281 / 351 | 시간 10[s] | 손실 0.29
# | 에폭 24 |  반복 301 / 351 | 시간 10[s] | 손실 0.28
# | 에폭 24 |  반복 321 / 351 | 시간 11[s] | 손실 0.27
# | 에폭 24 |  반복 341 / 351 | 시간 12[s] | 손실 0.29
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# 검증 정확도 51.980%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 25 |  반복 61 / 351 | 시간 2[s] | 손실 0.26
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.26
# | 에폭 25 |  반복 101 / 351 | 시간 3[s] | 손실 0.27
# | 에폭 25 |  반복 121 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 25 |  반복 141 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 25 |  반복 161 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 25 |  반복 181 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 25 |  반복 201 / 351 | 시간 7[s] | 손실 0.27
# | 에폭 25 |  반복 221 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 25 |  반복 241 / 351 | 시간 8[s] | 손실 0.27
# | 에폭 25 |  반복 261 / 351 | 시간 9[s] | 손실 0.28
# | 에폭 25 |  반복 281 / 351 | 시간 10[s] | 손실 0.28
# | 에폭 25 |  반복 301 / 351 | 시간 10[s] | 손실 0.27
# | 에폭 25 |  반복 321 / 351 | 시간 11[s] | 손실 0.28
# | 에폭 25 |  반복 341 / 351 | 시간 12[s] | 손실 0.28
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# 검증 정확도 54.260%
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]

    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout


class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled


class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss

    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

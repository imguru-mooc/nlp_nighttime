# %% [markdown]
# ### LSTM을 사용한 언어 모델

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %% [markdown]
# ### 학습을 위한 코드

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# Downloading ptb.test.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10000.25
# | 에폭 1 |  반복 21 / 1327 | 시간 6[s] | 퍼플렉서티 2797.19
# | 에폭 1 |  반복 41 / 1327 | 시간 11[s] | 퍼플렉서티 1213.15
# | 에폭 1 |  반복 61 / 1327 | 시간 17[s] | 퍼플렉서티 918.72
# | 에폭 1 |  반복 81 / 1327 | 시간 23[s] | 퍼플렉서티 784.45
# | 에폭 1 |  반복 101 / 1327 | 시간 29[s] | 퍼플렉서티 665.69
# | 에폭 1 |  반복 121 / 1327 | 시간 35[s] | 퍼플렉서티 642.76
# | 에폭 1 |  반복 141 / 1327 | 시간 41[s] | 퍼플렉서티 586.43
# | 에폭 1 |  반복 161 / 1327 | 시간 46[s] | 퍼플렉서티 580.25
# | 에폭 1 |  반복 181 / 1327 | 시간 52[s] | 퍼플렉서티 579.78
# | 에폭 1 |  반복 201 / 1327 | 시간 57[s] | 퍼플렉서티 509.10
# | 에폭 1 |  반복 221 / 1327 | 시간 63[s] | 퍼플렉서티 493.81
# | 에폭 1 |  반복 241 / 1327 | 시간 69[s] | 퍼플렉서티 435.06
# | 에폭 1 |  반복 261 / 1327 | 시간 75[s] | 퍼플렉서티 451.04
# | 에폭 1 |  반복 281 / 1327 | 시간 81[s] | 퍼플렉서티 454.53
# | 에폭 1 |  반복 301 / 1327 | 시간 86[s] | 퍼플렉서티 388.52
# | 에폭 1 |  반복 321 / 1327 | 시간 92[s] | 퍼플렉서티 341.81
# | 에폭 1 |  반복 341 / 1327 | 시간 98[s] | 퍼플렉서티 391.15
# | 에폭 1 |  반복 361 / 1327 | 시간 103[s] | 퍼플렉서티 404.77
# | 에폭 1 |  반복 381 / 1327 | 시간 109[s] | 퍼플렉서티 331.32
# | 에폭 1 |  반복 401 / 1327 | 시간 115[s] | 퍼플렉서티 349.41
# | 에폭 1 |  반복 421 / 1327 | 시간 121[s] | 퍼플렉서티 339.91
# | 에폭 1 |  반복 441 / 1327 | 시간 126[s] | 퍼플렉서티 331.04
# | 에폭 1 |  반복 461 / 1327 | 시간 132[s] | 퍼플렉서티 321.82
# | 에폭 1 |  반복 481 / 1327 | 시간 138[s] | 퍼플렉서티 302.96
# | 에폭 1 |  반복 501 / 1327 | 시간 144[s] | 퍼플렉서티 311.85
# | 에폭 1 |  반복 521 / 1327 | 시간 150[s] | 퍼플렉서티 300.88
# | 에폭 1 |  반복 541 / 1327 | 시간 156[s] | 퍼플렉서티 314.06
# | 에폭 1 |  반복 561 / 1327 | 시간 162[s] | 퍼플렉서티 285.18
# | 에폭 1 |  반복 581 / 1327 | 시간 167[s] | 퍼플렉서티 256.88
# | 에폭 1 |  반복 601 / 1327 | 시간 173[s] | 퍼플렉서티 331.92
# | 에폭 1 |  반복 621 / 1327 | 시간 179[s] | 퍼플렉서티 314.74
# | 에폭 1 |  반복 641 / 1327 | 시간 185[s] | 퍼플렉서티 281.53
# | 에폭 1 |  반복 661 / 1327 | 시간 190[s] | 퍼플렉서티 265.89
# | 에폭 1 |  반복 681 / 1327 | 시간 196[s] | 퍼플렉서티 227.97
# | 에폭 1 |  반복 701 / 1327 | 시간 202[s] | 퍼플렉서티 249.05
# | 에폭 1 |  반복 721 / 1327 | 시간 208[s] | 퍼플렉서티 259.38
# | 에폭 1 |  반복 741 / 1327 | 시간 213[s] | 퍼플렉서티 221.61
# | 에폭 1 |  반복 761 / 1327 | 시간 219[s] | 퍼플렉서티 230.82
# | 에폭 1 |  반복 781 / 1327 | 시간 225[s] | 퍼플렉서티 219.71
# | 에폭 1 |  반복 801 / 1327 | 시간 231[s] | 퍼플렉서티 241.05
# | 에폭 1 |  반복 821 / 1327 | 시간 237[s] | 퍼플렉서티 225.40
# | 에폭 1 |  반복 841 / 1327 | 시간 243[s] | 퍼플렉서티 230.99
# | 에폭 1 |  반복 861 / 1327 | 시간 249[s] | 퍼플렉서티 220.91
# | 에폭 1 |  반복 881 / 1327 | 시간 254[s] | 퍼플렉서티 204.79
# | 에폭 1 |  반복 901 / 1327 | 시간 260[s] | 퍼플렉서티 252.60
# | 에폭 1 |  반복 921 / 1327 | 시간 266[s] | 퍼플렉서티 227.82
# | 에폭 1 |  반복 941 / 1327 | 시간 272[s] | 퍼플렉서티 227.91
# | 에폭 1 |  반복 961 / 1327 | 시간 277[s] | 퍼플렉서티 244.68
# | 에폭 1 |  반복 981 / 1327 | 시간 283[s] | 퍼플렉서티 229.17
# | 에폭 1 |  반복 1001 / 1327 | 시간 289[s] | 퍼플렉서티 193.57
# | 에폭 1 |  반복 1021 / 1327 | 시간 295[s] | 퍼플렉서티 226.19
# | 에폭 1 |  반복 1041 / 1327 | 시간 301[s] | 퍼플렉서티 206.66
# | 에폭 1 |  반복 1061 / 1327 | 시간 306[s] | 퍼플렉서티 196.15
# | 에폭 1 |  반복 1081 / 1327 | 시간 312[s] | 퍼플렉서티 167.84
# | 에폭 1 |  반복 1101 / 1327 | 시간 318[s] | 퍼플렉서티 193.43
# | 에폭 1 |  반복 1121 / 1327 | 시간 324[s] | 퍼플렉서티 226.84
# | 에폭 1 |  반복 1141 / 1327 | 시간 330[s] | 퍼플렉서티 207.33
# | 에폭 1 |  반복 1161 / 1327 | 시간 335[s] | 퍼플렉서티 197.83
# | 에폭 1 |  반복 1181 / 1327 | 시간 341[s] | 퍼플렉서티 188.33
# | 에폭 1 |  반복 1201 / 1327 | 시간 347[s] | 퍼플렉서티 161.95
# | 에폭 1 |  반복 1221 / 1327 | 시간 353[s] | 퍼플렉서티 159.32
# | 에폭 1 |  반복 1241 / 1327 | 시간 359[s] | 퍼플렉서티 188.17
# | 에폭 1 |  반복 1261 / 1327 | 시간 364[s] | 퍼플렉서티 171.29
# | 에폭 1 |  반복 1281 / 1327 | 시간 370[s] | 퍼플렉서티 176.88
# | 에폭 1 |  반복 1301 / 1327 | 시간 376[s] | 퍼플렉서티 220.93
# | 에폭 1 |  반복 1321 / 1327 | 시간 382[s] | 퍼플렉서티 209.89
# | 에폭 2 |  반복 1 / 1327 | 시간 384[s] | 퍼플렉서티 222.52
# | 에폭 2 |  반복 21 / 1327 | 시간 389[s] | 퍼플렉서티 203.38
# | 에폭 2 |  반복 41 / 1327 | 시간 395[s] | 퍼플렉서티 188.41
# | 에폭 2 |  반복 61 / 1327 | 시간 401[s] | 퍼플렉서티 175.41
# | 에폭 2 |  반복 81 / 1327 | 시간 407[s] | 퍼플렉서티 157.88
# | 에폭 2 |  반복 101 / 1327 | 시간 413[s] | 퍼플렉서티 152.40
# | 에폭 2 |  반복 121 / 1327 | 시간 419[s] | 퍼플렉서티 159.28
# | 에폭 2 |  반복 141 / 1327 | 시간 425[s] | 퍼플렉서티 176.66
# | 에폭 2 |  반복 161 / 1327 | 시간 430[s] | 퍼플렉서티 191.13
# | 에폭 2 |  반복 181 / 1327 | 시간 436[s] | 퍼플렉서티 198.18
# | 에폭 2 |  반복 201 / 1327 | 시간 442[s] | 퍼플렉서티 184.35
# | 에폭 2 |  반복 221 / 1327 | 시간 447[s] | 퍼플렉서티 182.98
# | 에폭 2 |  반복 241 / 1327 | 시간 453[s] | 퍼플렉서티 176.67
# | 에폭 2 |  반복 261 / 1327 | 시간 458[s] | 퍼플렉서티 182.80
# | 에폭 2 |  반복 281 / 1327 | 시간 464[s] | 퍼플렉서티 184.52
# | 에폭 2 |  반복 301 / 1327 | 시간 470[s] | 퍼플렉서티 165.27
# | 에폭 2 |  반복 321 / 1327 | 시간 476[s] | 퍼플렉서티 137.28
# | 에폭 2 |  반복 341 / 1327 | 시간 481[s] | 퍼플렉서티 169.21
# | 에폭 2 |  반복 361 / 1327 | 시간 487[s] | 퍼플렉서티 194.98
# | 에폭 2 |  반복 381 / 1327 | 시간 492[s] | 퍼플렉서티 152.29
# | 에폭 2 |  반복 401 / 1327 | 시간 498[s] | 퍼플렉서티 167.11
# | 에폭 2 |  반복 421 / 1327 | 시간 503[s] | 퍼플렉서티 154.81
# | 에폭 2 |  반복 441 / 1327 | 시간 509[s] | 퍼플렉서티 162.13
# | 에폭 2 |  반복 461 / 1327 | 시간 515[s] | 퍼플렉서티 154.60
# | 에폭 2 |  반복 481 / 1327 | 시간 521[s] | 퍼플렉서티 157.16
# | 에폭 2 |  반복 501 / 1327 | 시간 527[s] | 퍼플렉서티 168.77
# | 에폭 2 |  반복 521 / 1327 | 시간 533[s] | 퍼플렉서티 171.51
# | 에폭 2 |  반복 541 / 1327 | 시간 538[s] | 퍼플렉서티 173.31
# | 에폭 2 |  반복 561 / 1327 | 시간 544[s] | 퍼플렉서티 154.38
# | 에폭 2 |  반복 581 / 1327 | 시간 549[s] | 퍼플렉서티 137.98
# | 에폭 2 |  반복 601 / 1327 | 시간 556[s] | 퍼플렉서티 188.46
# | 에폭 2 |  반복 621 / 1327 | 시간 562[s] | 퍼플렉서티 179.73
# | 에폭 2 |  반복 641 / 1327 | 시간 568[s] | 퍼플렉서티 164.20
# | 에폭 2 |  반복 661 / 1327 | 시간 573[s] | 퍼플렉서티 153.69
# | 에폭 2 |  반복 681 / 1327 | 시간 580[s] | 퍼플렉서티 130.41
# | 에폭 2 |  반복 701 / 1327 | 시간 585[s] | 퍼플렉서티 149.39
# | 에폭 2 |  반복 721 / 1327 | 시간 591[s] | 퍼플렉서티 158.16
# | 에폭 2 |  반복 741 / 1327 | 시간 596[s] | 퍼플렉서티 133.64
# | 에폭 2 |  반복 761 / 1327 | 시간 602[s] | 퍼플렉서티 131.70
# | 에폭 2 |  반복 781 / 1327 | 시간 608[s] | 퍼플렉서티 135.35
# | 에폭 2 |  반복 801 / 1327 | 시간 613[s] | 퍼플렉서티 146.05
# | 에폭 2 |  반복 821 / 1327 | 시간 619[s] | 퍼플렉서티 142.65
# | 에폭 2 |  반복 841 / 1327 | 시간 625[s] | 퍼플렉서티 144.76
# | 에폭 2 |  반복 861 / 1327 | 시간 631[s] | 퍼플렉서티 146.28
# | 에폭 2 |  반복 881 / 1327 | 시간 637[s] | 퍼플렉서티 130.02
# | 에폭 2 |  반복 901 / 1327 | 시간 643[s] | 퍼플렉서티 165.34
# | 에폭 2 |  반복 921 / 1327 | 시간 649[s] | 퍼플렉서티 146.62
# | 에폭 2 |  반복 941 / 1327 | 시간 654[s] | 퍼플렉서티 152.01
# | 에폭 2 |  반복 961 / 1327 | 시간 660[s] | 퍼플렉서티 161.32
# | 에폭 2 |  반복 981 / 1327 | 시간 666[s] | 퍼플렉서티 154.47
# | 에폭 2 |  반복 1001 / 1327 | 시간 671[s] | 퍼플렉서티 130.79
# | 에폭 2 |  반복 1021 / 1327 | 시간 677[s] | 퍼플렉서티 155.07
# | 에폭 2 |  반복 1041 / 1327 | 시간 683[s] | 퍼플렉서티 142.01
# | 에폭 2 |  반복 1061 / 1327 | 시간 689[s] | 퍼플렉서티 127.42
# | 에폭 2 |  반복 1081 / 1327 | 시간 695[s] | 퍼플렉서티 110.04
# | 에폭 2 |  반복 1101 / 1327 | 시간 701[s] | 퍼플렉서티 121.04
# | 에폭 2 |  반복 1121 / 1327 | 시간 707[s] | 퍼플렉서티 152.42
# | 에폭 2 |  반복 1141 / 1327 | 시간 713[s] | 퍼플렉서티 140.97
# | 에폭 2 |  반복 1161 / 1327 | 시간 718[s] | 퍼플렉서티 133.39
# | 에폭 2 |  반복 1181 / 1327 | 시간 724[s] | 퍼플렉서티 131.89
# | 에폭 2 |  반복 1201 / 1327 | 시간 730[s] | 퍼플렉서티 111.73
# | 에폭 2 |  반복 1221 / 1327 | 시간 736[s] | 퍼플렉서티 108.55
# | 에폭 2 |  반복 1241 / 1327 | 시간 741[s] | 퍼플렉서티 130.49
# | 에폭 2 |  반복 1261 / 1327 | 시간 747[s] | 퍼플렉서티 124.29
# | 에폭 2 |  반복 1281 / 1327 | 시간 753[s] | 퍼플렉서티 122.57
# | 에폭 2 |  반복 1301 / 1327 | 시간 759[s] | 퍼플렉서티 156.06
# | 에폭 2 |  반복 1321 / 1327 | 시간 764[s] | 퍼플렉서티 152.80
# | 에폭 3 |  반복 1 / 1327 | 시간 766[s] | 퍼플렉서티 160.34
# | 에폭 3 |  반복 21 / 1327 | 시간 772[s] | 퍼플렉서티 144.58
# | 에폭 3 |  반복 41 / 1327 | 시간 778[s] | 퍼플렉서티 133.45
# | 에폭 3 |  반복 61 / 1327 | 시간 783[s] | 퍼플렉서티 126.36
# | 에폭 3 |  반복 81 / 1327 | 시간 789[s] | 퍼플렉서티 114.28
# | 에폭 3 |  반복 101 / 1327 | 시간 795[s] | 퍼플렉서티 105.37
# | 에폭 3 |  반복 121 / 1327 | 시간 801[s] | 퍼플렉서티 115.03
# | 에폭 3 |  반복 141 / 1327 | 시간 806[s] | 퍼플렉서티 124.21
# | 에폭 3 |  반복 161 / 1327 | 시간 812[s] | 퍼플렉서티 140.54
# | 에폭 3 |  반복 181 / 1327 | 시간 818[s] | 퍼플렉서티 150.51
# | 에폭 3 |  반복 201 / 1327 | 시간 823[s] | 퍼플렉서티 139.93
# | 에폭 3 |  반복 221 / 1327 | 시간 830[s] | 퍼플렉서티 140.90
# | 에폭 3 |  반복 241 / 1327 | 시간 835[s] | 퍼플렉서티 134.35
# | 에폭 3 |  반복 261 / 1327 | 시간 841[s] | 퍼플렉서티 137.54
# | 에폭 3 |  반복 281 / 1327 | 시간 847[s] | 퍼플렉서티 140.45
# | 에폭 3 |  반복 301 / 1327 | 시간 853[s] | 퍼플렉서티 123.93
# | 에폭 3 |  반복 321 / 1327 | 시간 859[s] | 퍼플렉서티 102.09
# | 에폭 3 |  반복 341 / 1327 | 시간 864[s] | 퍼플렉서티 124.18
# | 에폭 3 |  반복 361 / 1327 | 시간 870[s] | 퍼플렉서티 150.17
# | 에폭 3 |  반복 381 / 1327 | 시간 876[s] | 퍼플렉서티 113.74
# | 에폭 3 |  반복 401 / 1327 | 시간 882[s] | 퍼플렉서티 129.15
# | 에폭 3 |  반복 421 / 1327 | 시간 887[s] | 퍼플렉서티 113.26
# | 에폭 3 |  반복 441 / 1327 | 시간 893[s] | 퍼플렉서티 122.80
# | 에폭 3 |  반복 461 / 1327 | 시간 899[s] | 퍼플렉서티 116.49
